# %% [markdown]
# # Smart Agri AI - Complete Training Notebook
# This notebook trains:
# 1. Disease CNN model using `kagglehub` dataset
# 2. Cost estimator model using synthetic Himachal-style 20k dataset
# 3. Saves models for FastAPI app

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().resolve().parents[0] if (Path.cwd() / 'training').exists() else Path.cwd()
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))
print(ROOT)

# %%
# !python training/train_disease_model.py

# %%
# !python training/generate_cost_dataset_and_train.py

# %% [markdown]
# After training, run API server:
# ```bash
# uvicorn backend.app.main:app --reload --port 8000
# ```
